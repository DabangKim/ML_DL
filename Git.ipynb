# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab Notebooks/ML_DL
# Out:
# /content/drive/MyDrive/Colab Notebooks/ML_DL

# %%
import os
from getpass import getpass

# GitHub 토큰을 입력창을 통해 받음
token = getpass("🔒 GitHub Personal Access Token 입력: ")

# .netrc 파일 생성
with open(os.path.expanduser('~/.netrc'), 'w') as f:
    f.write(f"machine github.com\nlogin DabangKim\npassword {token}\n")

# 권한 설정 (필수)
os.chmod(os.path.expanduser('~/.netrc'), 0o600)
print("✅ .netrc 파일 생성 완료")
# Out:
# 🔒 GitHub Personal Access Token 입력: ··········
# ✅ .netrc 파일 생성 완료

# %%
# Git 사용자 정보 설정
# !git config --global user.email "nzkiwiking@gmail.com"
# !git config --global user.name "DabangKim"

# # Git 초기화 및 원격 저장소 연결
# !git init
# !git remote add origin https://github.com/DabangKim/ML_DL.git

# %%
# 변경 사항 추가, 커밋, 푸시
# !git add .
# !git commit -m "k-Nearest Neighbors"
# !git branch -M main
# !git push origin main

# %%
# !git add .
# !git commit -m "CH08)이미지를_위한_인공_신경망"
# !git push origin main
# Out:
# [main 09bc0bb] CH08)이미지를_위한_인공_신경망
#  3 files changed, 3 insertions(+), 2 deletions(-)
#  rewrite "CH07)\341\204\203\341\205\265\341\206\270\341\204\205\341\205\245\341\204\202\341\205\265\341\206\274\341\204\213\341\205\263\341\206\257_\341\204\211\341\205\265\341\204\214\341\205\241\341\206\250\341\204\222\341\205\241\341\206\270\341\204\202\341\205\265\341\204\203\341\205\241.ipynb" (90%)
#  create mode 100644 "CH08)\341\204\213\341\205\265\341\204\206\341\205\265\341\204\214\341\205\265\341\204\205\341\205\263\341\206\257_\341\204\213\341\205\261\341\204\222\341\205\241\341\206\253_\341\204\213\341\205\265\341\206\253\341\204\200\341\205\251\341\206\274_\341\204\211\341\205\265\341\206\253\341\204\200\341\205\247\341\206\274\341\204\206\341\205\241\341\206\274.ipynb"
#  rewrite Git.ipynb (90%)
# Enumerating objects: 8, done.
# Counting objects: 100% (8/8), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (5/5), done.
# ...
