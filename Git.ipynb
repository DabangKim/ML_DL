# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab Notebooks/ML_DL
# Out:
# /content/drive/MyDrive/Colab Notebooks/ML_DL

# %%
import os
from getpass import getpass

# GitHub 토큰을 입력창을 통해 받음
token = getpass("🔒 GitHub Personal Access Token 입력: ")

# .netrc 파일 생성
with open(os.path.expanduser('~/.netrc'), 'w') as f:
    f.write(f"machine github.com\nlogin DabangKim\npassword {token}\n")

# 권한 설정 (필수)
os.chmod(os.path.expanduser('~/.netrc'), 0o600)
print("✅ .netrc 파일 생성 완료")
# Out:
# 🔒 GitHub Personal Access Token 입력: ··········
# ✅ .netrc 파일 생성 완료

# %%
# Git 사용자 정보 설정
# !git config --global user.email "nzkiwiking@gmail.com"
# !git config --global user.name "DabangKim"

# # Git 초기화 및 원격 저장소 연결
# !git init
# !git remote add origin https://github.com/DabangKim/ML_DL.git

# %%
# 변경 사항 추가, 커밋, 푸시
# !git add .
# !git commit -m "k-Nearest Neighbors"
# !git branch -M main
# !git push origin main

# %%
# !git add .
# !git commit -m "CH04)다양한_분류_알고리즘"
# !git push origin main
# Out:
# [main d1bc2db] CH03)회귀_알고리즘과_모델_규제
#  2 files changed, 2 insertions(+), 1 deletion(-)
#  create mode 100644 "CH03)\341\204\222\341\205\254\341\204\200\341\205\261_\341\204\213\341\205\241\341\206\257\341\204\200\341\205\251\341\204\205\341\205\265\341\204\214\341\205\263\341\206\267\341\204\200\341\205\252_\341\204\206\341\205\251\341\204\203\341\205\246\341\206\257_\341\204\200\341\205\262\341\204\214\341\205\246.ipynb"
#  rewrite Git.ipynb (86%)
# Enumerating objects: 6, done.
# Counting objects: 100% (6/6), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 128.97 KiB | 5.61 MiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/DabangKim/ML_DL.git
#    ac64143..d1bc2db  main -> main
