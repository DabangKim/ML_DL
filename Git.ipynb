# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cd /content/drive/MyDrive/Colab Notebooks/ML_DL

# %%
import os
from getpass import getpass

# GitHub 토큰을 입력창을 통해 받음
token = getpass("🔒 GitHub Personal Access Token 입력: ")

# .netrc 파일 생성
with open(os.path.expanduser('~/.netrc'), 'w') as f:
    f.write(f"machine github.com\nlogin DabangKim\npassword {token}\n")

# 권한 설정 (필수)
os.chmod(os.path.expanduser('~/.netrc'), 0o600)
print("✅ .netrc 파일 생성 완료")

# %%
# Git 사용자 정보 설정
# !git config --global user.email "nzkiwiking@gmail.com"
# !git config --global user.name "DabangKim"

# # Git 초기화 및 원격 저장소 연결
# !git init
# !git remote add origin https://github.com/DabangKim/ML_DL.git

# %%
# 변경 사항 추가, 커밋, 푸시
# !git add .
# !git commit -m "k-Nearest Neighbors"
# !git branch -M main
# !git push origin main

# %%
# !git add .
# !git commit -m "CH07)딥러닝을_시작합니다"
# !git push origin main
# Out:
# [main 05b372c] CH05)트리_알고리즘 & CH06)비지도_학습
#  3 files changed, 3 insertions(+), 1 deletion(-)
#  create mode 100644 "CH05)\341\204\220\341\205\263\341\204\205\341\205\265_\341\204\213\341\205\241\341\206\257\341\204\200\341\205\251\341\204\205\341\205\265\341\204\214\341\205\263\341\206\267.ipynb"
#  create mode 100644 "CH06)\341\204\207\341\205\265\341\204\214\341\205\265\341\204\203\341\205\251_\341\204\222\341\205\241\341\206\250\341\204\211\341\205\263\341\206\270.ipynb"
#  rewrite Git.ipynb (83%)
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 5.37 MiB | 7.66 MiB/s, done.
# Total 5 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/DabangKim/ML_DL.git
#    3d02853..05b372c  main -> main
